# %%
import os.path
import cv2
import os
import json
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def extract_video_frames(video_filename):
    video = cv2.VideoCapture(video_filename)

    try:
        video_path = Path(video_filename)
        video_parent_directory_path = os.path.dirname(video_path)
        # creating a folder named VideoFrames
        video_frames_path_name = f'{video_parent_directory_path}/VideoFrames'
        if not os.path.exists(video_frames_path_name):
            os.makedirs(video_frames_path_name)

    # if not created then raise error
    except OSError:
        print (f'Error: Creating directory {video_frames_path_name}')

    # frame
    current_frame = 0

    while(True):

        # reading from frame
        ret, frame = video.read()

        if ret:
            # if video is still left continue creating images
            frame_name = f'{video_parent_directory_path}/VideoFrames/frame{current_frame}.jpg'
            print ('Creating...' + frame_name)

            # writing the extracted images
            cv2.imwrite(frame_name, frame)

            current_frame += 1
        else:
            break


    return current_frame

def extract_depth_map(depth_bytes_filename, depth_metadata_filename):
    # Parse the metadata JSON so we can understand how to parse bytes file
    f = open(depth_metadata_filename)
    metadata_json = json.load(f)
    print("Printing depth metadata:")
    print(metadata_json)
    
    depth_map_number_of_bytes = metadata_json['bytesPerRow'] * metadata_json['height']
    
    depth_bytes_file = open(depth_bytes_filename, 'rb')
    
    try:
        depth_bytes_path = Path(depth_bytes_filename)
        depth_bytes_parent_directory_path = os.path.dirname(depth_bytes_path)
        # creating a folder named DepthMaps
        depth_maps_path_name = f'{depth_bytes_parent_directory_path}/DepthMaps'
        if not os.path.exists(depth_maps_path_name):
            os.makedirs(depth_maps_path_name)

    # if not created then raise error
    except OSError:
        print (f'Error: Creating directory {depth_maps_path_name}')
        
    # frame
    current_frame = 0

    while(True):

        # reading from buffer
        depth_map_buffer = depth_bytes_file.read(depth_map_number_of_bytes)
        if depth_map_buffer:
            deserialized_bytes = np.frombuffer(depth_map_buffer, dtype=np.float32)
            depth_map = np.reshape(deserialized_bytes, newshape=(metadata_json['height'], metadata_json['width']))
#             print("Printing depth map:")
#             print(depth_map)

#             print("Printing depth map shape:")
#             print(depth_map.shape)
            
            depth_map_name = f'{depth_bytes_parent_directory_path}/DepthMaps/frame{current_frame}.npy'
            print ('Creating...' + depth_map_name)
            
            np.save(depth_map_name, depth_map)
            
            current_frame += 1
        else:
            break
            
    return current_frame  

def extract_frames_and_depth_map(video_filename, depth_bytes_filename, depth_metadata_filename):
    video_frames_count = extract_video_frames(video_filename)
    depth_maps_count = extract_depth_map(depth_bytes_filename, depth_metadata_filename)
    print(f"Number of video frames:{video_frames_count}")
    print(f"Number of depth maps:{depth_maps_count}")
    return (video_frames_count == depth_maps_count), video_frames_count
    
def plot_video_and_depth_map(frame_filename, depth_map_filename):
    depth_map = np.load(depth_map_filename)
    frame_image = mpimg.imread(frame_filename)
    
    smallest_depth_value = depth_map.min()
    largest_depth_value = depth_map.max()
#     print("Printing depth map:")
#     print(depth_map)
#     print(f"Min value: {smallest_depth_value}")
#     print(f"Max value: {largest_depth_value}")
#     print("\n")
    
    fig1, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
    fig1.suptitle(f'Depth Color Map\nColor map range is from {smallest_depth_value}m to {largest_depth_value}m\nDepth Map Filename: {depth_map_filename}\nImage Filename: {frame_filename}')

    ax1.set_title('Color map of depth')
    ax1.set_xlabel('Pixel column')
    ax1.set_ylabel('Pixel row')
    ax1img = ax1.imshow(depth_map, cmap="plasma", vmin=smallest_depth_value, vmax=largest_depth_value)
    fig1.colorbar(ax1img, ax = ax1)

    ax2.set_title('RGB image')
    ax2.set_xlabel('Pixel column')
    ax2.set_ylabel('Pixel row')
    ax2.imshow(frame_image)

    fig1.tight_layout()
    
def get_immediate_depth_data_subdirectories(a_dir):
    return [name for name in os.listdir(a_dir)
            if os.path.isdir(os.path.join(a_dir, name)) and name.startswith('DepthData')] 

def main():
    depth_data_subdirectories = get_immediate_depth_data_subdirectories('.')
    plot_interval = 5
    for directory in depth_data_subdirectories:
        extraction_success, frames_count = extract_frames_and_depth_map(f'{directory}/video.mp4', f'{directory}/DepthDataBytes', f'{directory}/DepthDataMetadata.json')
        if extraction_success:
            for i in range(frames_count):
                if i % plot_interval == 0:
                    frame_filename = f'{directory}/VideoFrames/frame{i}.jpg'
                    depth_map_filename = f'{directory}/DepthMaps/frame{i}.npy'
                    plot_video_and_depth_map(frame_filename, depth_map_filename)
                
        else:
            print("Error: Video frame count and depth map count is not the same")

# %%
main()
# Out:
# Creating...DepthData 2/VideoFrames/frame0.jpg
# Creating...DepthData 2/VideoFrames/frame1.jpg
# Creating...DepthData 2/VideoFrames/frame2.jpg
# Creating...DepthData 2/VideoFrames/frame3.jpg
# Creating...DepthData 2/VideoFrames/frame4.jpg
# Creating...DepthData 2/VideoFrames/frame5.jpg
# Creating...DepthData 2/VideoFrames/frame6.jpg
# Creating...DepthData 2/VideoFrames/frame7.jpg
# Creating...DepthData 2/VideoFrames/frame8.jpg
# Creating...DepthData 2/VideoFrames/frame9.jpg
# Creating...DepthData 2/VideoFrames/frame10.jpg
# Creating...DepthData 2/VideoFrames/frame11.jpg
# Creating...DepthData 2/VideoFrames/frame12.jpg
# Creating...DepthData 2/VideoFrames/frame13.jpg
# Creating...DepthData 2/VideoFrames/frame14.jpg
# Creating...DepthData 2/VideoFrames/frame15.jpg
# Creating...DepthData 2/VideoFrames/frame16.jpg
# Creating...DepthData 2/VideoFrames/frame17.jpg
# Creating...DepthData 2/VideoFrames/frame18.jpg
# Creating...DepthData 2/VideoFrames/frame19.jpg
# Creating...DepthData 2/VideoFrames/frame20.jpg
# Creating...DepthData 2/VideoFrames/frame21.jpg
# Creating...DepthData 2/VideoFrames/frame22.jpg
# Creating...DepthData 2/VideoFrames/frame23.jpg
# Creating...DepthData 2/VideoFrames/frame24.jpg
# Creating...DepthData 2/VideoFrames/frame25.jpg
# Creating...DepthData 2/VideoFrames/frame26.jpg
# Creating...DepthData 2/VideoFrames/frame27.jpg
# Creating...DepthData 2/VideoFrames/frame28.jpg
# Creating...DepthData 2/VideoFrames/frame29.jpg
# Creating...DepthData 2/VideoFrames/frame30.jpg
# Creating...DepthData 2/VideoFrames/frame31.jpg
# Creating...DepthData 2/VideoFrames/frame32.jpg
# Creating...DepthData 2/VideoFrames/frame33.jpg
# Creating...DepthData 2/VideoFrames/frame34.jpg
# Creating...DepthData 2/VideoFrames/frame35.jpg
# Creating...DepthData 2/VideoFrames/frame36.jpg
# Creating...DepthData 2/VideoFrames/frame37.jpg
# Creating...DepthData 2/VideoFrames/frame38.jpg
# Creating...DepthData 2/VideoFrames/frame39.jpg
# Creating...DepthData 2/VideoFrames/frame40.jpg
# Creating...DepthData 2/VideoFrames/frame41.jpg
# Creating...DepthData 2/VideoFrames/frame42.jpg
# Creating...DepthData 2/VideoFrames/frame43.jpg
# Creating...DepthData 2/VideoFrames/frame44.jpg
# Creating...DepthData 2/VideoFrames/frame45.jpg
# Creating...DepthData 2/VideoFrames/frame46.jpg
# Creating...DepthData 2/VideoFrames/frame47.jpg
# Creating...DepthData 2/VideoFrames/frame48.jpg
# Creating...DepthData 2/VideoFrames/frame49.jpg
# Creating...DepthData 2/VideoFrames/frame50.jpg
# Creating...DepthData 2/VideoFrames/frame51.jpg
# Creating...DepthData 2/VideoFrames/frame52.jpg
# Creating...DepthData 2/VideoFrames/frame53.jpg
# Creating...DepthData 2/VideoFrames/frame54.jpg
# Creating...DepthData 2/VideoFrames/frame55.jpg
# Creating...DepthData 2/VideoFrames/frame56.jpg
# Creating...DepthData 2/VideoFrames/frame57.jpg
# Creating...DepthData 2/VideoFrames/frame58.jpg
# Creating...DepthData 2/VideoFrames/frame59.jpg
# Creating...DepthData 2/VideoFrames/frame60.jpg
# Creating...DepthData 2/VideoFrames/frame61.jpg
# Creating...DepthData 2/VideoFrames/frame62.jpg
# Creating...DepthData 2/VideoFrames/frame63.jpg
# Creating...DepthData 2/VideoFrames/frame64.jpg
# Creating...DepthData 2/VideoFrames/frame65.jpg
# Creating...DepthData 2/VideoFrames/frame66.jpg
# Creating...DepthData 2/VideoFrames/frame67.jpg
# Creating...DepthData 2/VideoFrames/frame68.jpg
# Creating...DepthData 2/VideoFrames/frame69.jpg
# Creating...DepthData 2/VideoFrames/frame70.jpg
# Creating...DepthData 2/VideoFrames/frame71.jpg
# Creating...DepthData 2/VideoFrames/frame72.jpg
# Creating...DepthData 2/VideoFrames/frame73.jpg
# Creating...DepthData 2/VideoFrames/frame74.jpg
# Creating...DepthData 2/VideoFrames/frame75.jpg
# Creating...DepthData 2/VideoFrames/frame76.jpg
# Creating...DepthData 2/VideoFrames/frame77.jpg
# Creating...DepthData 2/VideoFrames/frame78.jpg
# Creating...DepthData 2/VideoFrames/frame79.jpg
# Creating...DepthData 2/VideoFrames/frame80.jpg
# Creating...DepthData 2/VideoFrames/frame81.jpg
# Printing depth metadata:
# {'pixelFormatType': 'kCVPixelFormatType_DepthFloat32', 'width': 144, 'height': 256, 'bytesPerRow': 576}
# Creating...DepthData 2/DepthMaps/frame0.npy
# Creating...DepthData 2/DepthMaps/frame1.npy
# Creating...DepthData 2/DepthMaps/frame2.npy
# Creating...DepthData 2/DepthMaps/frame3.npy
# Creating...DepthData 2/DepthMaps/frame4.npy
# Creating...DepthData 2/DepthMaps/frame5.npy
# Creating...DepthData 2/DepthMaps/frame6.npy
# Creating...DepthData 2/DepthMaps/frame7.npy
# Creating...DepthData 2/DepthMaps/frame8.npy
# Creating...DepthData 2/DepthMaps/frame9.npy
# Creating...DepthData 2/DepthMaps/frame10.npy
# Creating...DepthData 2/DepthMaps/frame11.npy
# Creating...DepthData 2/DepthMaps/frame12.npy
# Creating...DepthData 2/DepthMaps/frame13.npy
# Creating...DepthData 2/DepthMaps/frame14.npy
# Creating...DepthData 2/DepthMaps/frame15.npy
# Creating...DepthData 2/DepthMaps/frame16.npy
# Creating...DepthData 2/DepthMaps/frame17.npy
# Creating...DepthData 2/DepthMaps/frame18.npy
# Creating...DepthData 2/DepthMaps/frame19.npy
# Creating...DepthData 2/DepthMaps/frame20.npy
# Creating...DepthData 2/DepthMaps/frame21.npy
# Creating...DepthData 2/DepthMaps/frame22.npy
# Creating...DepthData 2/DepthMaps/frame23.npy
# Creating...DepthData 2/DepthMaps/frame24.npy
# Creating...DepthData 2/DepthMaps/frame25.npy
# Creating...DepthData 2/DepthMaps/frame26.npy
# Creating...DepthData 2/DepthMaps/frame27.npy
# Creating...DepthData 2/DepthMaps/frame28.npy
# Creating...DepthData 2/DepthMaps/frame29.npy
# Creating...DepthData 2/DepthMaps/frame30.npy
# Creating...DepthData 2/DepthMaps/frame31.npy
# Creating...DepthData 2/DepthMaps/frame32.npy
# Creating...DepthData 2/DepthMaps/frame33.npy
# Creating...DepthData 2/DepthMaps/frame34.npy
# Creating...DepthData 2/DepthMaps/frame35.npy
# Creating...DepthData 2/DepthMaps/frame36.npy
# Creating...DepthData 2/DepthMaps/frame37.npy
# Creating...DepthData 2/DepthMaps/frame38.npy
# Creating...DepthData 2/DepthMaps/frame39.npy
# Creating...DepthData 2/DepthMaps/frame40.npy
# Creating...DepthData 2/DepthMaps/frame41.npy
# Creating...DepthData 2/DepthMaps/frame42.npy
# Creating...DepthData 2/DepthMaps/frame43.npy
# Creating...DepthData 2/DepthMaps/frame44.npy
# Creating...DepthData 2/DepthMaps/frame45.npy
# Creating...DepthData 2/DepthMaps/frame46.npy
# Creating...DepthData 2/DepthMaps/frame47.npy
# Creating...DepthData 2/DepthMaps/frame48.npy
# Creating...DepthData 2/DepthMaps/frame49.npy
# Creating...DepthData 2/DepthMaps/frame50.npy
# Creating...DepthData 2/DepthMaps/frame51.npy
# Creating...DepthData 2/DepthMaps/frame52.npy
# Creating...DepthData 2/DepthMaps/frame53.npy
# Creating...DepthData 2/DepthMaps/frame54.npy
# Creating...DepthData 2/DepthMaps/frame55.npy
# Creating...DepthData 2/DepthMaps/frame56.npy
# Creating...DepthData 2/DepthMaps/frame57.npy
# Creating...DepthData 2/DepthMaps/frame58.npy
# Creating...DepthData 2/DepthMaps/frame59.npy
# Creating...DepthData 2/DepthMaps/frame60.npy
# Creating...DepthData 2/DepthMaps/frame61.npy
# Creating...DepthData 2/DepthMaps/frame62.npy
# Creating...DepthData 2/DepthMaps/frame63.npy
# Creating...DepthData 2/DepthMaps/frame64.npy
# Creating...DepthData 2/DepthMaps/frame65.npy
# Creating...DepthData 2/DepthMaps/frame66.npy
# Creating...DepthData 2/DepthMaps/frame67.npy
# Creating...DepthData 2/DepthMaps/frame68.npy
# Creating...DepthData 2/DepthMaps/frame69.npy
# Creating...DepthData 2/DepthMaps/frame70.npy
# Creating...DepthData 2/DepthMaps/frame71.npy
# Creating...DepthData 2/DepthMaps/frame72.npy
# Creating...DepthData 2/DepthMaps/frame73.npy
# Creating...DepthData 2/DepthMaps/frame74.npy
# Creating...DepthData 2/DepthMaps/frame75.npy
# Creating...DepthData 2/DepthMaps/frame76.npy
# Creating...DepthData 2/DepthMaps/frame77.npy
# Creating...DepthData 2/DepthMaps/frame78.npy
# Creating...DepthData 2/DepthMaps/frame79.npy
# Creating...DepthData 2/DepthMaps/frame80.npy
# Creating...DepthData 2/DepthMaps/frame81.npy
# Number of video frames:82
# Number of depth maps:82
# Creating...DepthData 3/VideoFrames/frame0.jpg
# Creating...DepthData 3/VideoFrames/frame1.jpg
# Creating...DepthData 3/VideoFrames/frame2.jpg
# Creating...DepthData 3/VideoFrames/frame3.jpg
# Creating...DepthData 3/VideoFrames/frame4.jpg
# Creating...DepthData 3/VideoFrames/frame5.jpg
# Creating...DepthData 3/VideoFrames/frame6.jpg
# Creating...DepthData 3/VideoFrames/frame7.jpg
# Creating...DepthData 3/VideoFrames/frame8.jpg
# Creating...DepthData 3/VideoFrames/frame9.jpg
# Creating...DepthData 3/VideoFrames/frame10.jpg
# Creating...DepthData 3/VideoFrames/frame11.jpg
# Creating...DepthData 3/VideoFrames/frame12.jpg
# Creating...DepthData 3/VideoFrames/frame13.jpg
# Creating...DepthData 3/VideoFrames/frame14.jpg
# Creating...DepthData 3/VideoFrames/frame15.jpg
# Creating...DepthData 3/VideoFrames/frame16.jpg
# Creating...DepthData 3/VideoFrames/frame17.jpg
# Creating...DepthData 3/VideoFrames/frame18.jpg
# Creating...DepthData 3/VideoFrames/frame19.jpg
# Creating...DepthData 3/VideoFrames/frame20.jpg
# Creating...DepthData 3/VideoFrames/frame21.jpg
# Creating...DepthData 3/VideoFrames/frame22.jpg
# Creating...DepthData 3/VideoFrames/frame23.jpg
# Creating...DepthData 3/VideoFrames/frame24.jpg
# Creating...DepthData 3/VideoFrames/frame25.jpg
# Creating...DepthData 3/VideoFrames/frame26.jpg
# Creating...DepthData 3/VideoFrames/frame27.jpg
# Creating...DepthData 3/VideoFrames/frame28.jpg
# Creating...DepthData 3/VideoFrames/frame29.jpg
# Creating...DepthData 3/VideoFrames/frame30.jpg
# Creating...DepthData 3/VideoFrames/frame31.jpg
# Creating...DepthData 3/VideoFrames/frame32.jpg
# Creating...DepthData 3/VideoFrames/frame33.jpg
# Creating...DepthData 3/VideoFrames/frame34.jpg
# Creating...DepthData 3/VideoFrames/frame35.jpg
# Creating...DepthData 3/VideoFrames/frame36.jpg
# Creating...DepthData 3/VideoFrames/frame37.jpg
# Creating...DepthData 3/VideoFrames/frame38.jpg
# Creating...DepthData 3/VideoFrames/frame39.jpg
# Creating...DepthData 3/VideoFrames/frame40.jpg
# Creating...DepthData 3/VideoFrames/frame41.jpg
# Creating...DepthData 3/VideoFrames/frame42.jpg
# Creating...DepthData 3/VideoFrames/frame43.jpg
# Creating...DepthData 3/VideoFrames/frame44.jpg
# Creating...DepthData 3/VideoFrames/frame45.jpg
# Creating...DepthData 3/VideoFrames/frame46.jpg
# Creating...DepthData 3/VideoFrames/frame47.jpg
# Creating...DepthData 3/VideoFrames/frame48.jpg
# Creating...DepthData 3/VideoFrames/frame49.jpg
# Creating...DepthData 3/VideoFrames/frame50.jpg
# Creating...DepthData 3/VideoFrames/frame51.jpg
# Creating...DepthData 3/VideoFrames/frame52.jpg
# Creating...DepthData 3/VideoFrames/frame53.jpg
# Creating...DepthData 3/VideoFrames/frame54.jpg
# Creating...DepthData 3/VideoFrames/frame55.jpg
# Creating...DepthData 3/VideoFrames/frame56.jpg
# Creating...DepthData 3/VideoFrames/frame57.jpg
# Creating...DepthData 3/VideoFrames/frame58.jpg
# Creating...DepthData 3/VideoFrames/frame59.jpg
# Creating...DepthData 3/VideoFrames/frame60.jpg
# Creating...DepthData 3/VideoFrames/frame61.jpg
# Creating...DepthData 3/VideoFrames/frame62.jpg
# Creating...DepthData 3/VideoFrames/frame63.jpg
# Creating...DepthData 3/VideoFrames/frame64.jpg
# Creating...DepthData 3/VideoFrames/frame65.jpg
# Creating...DepthData 3/VideoFrames/frame66.jpg
# Creating...DepthData 3/VideoFrames/frame67.jpg
# Creating...DepthData 3/VideoFrames/frame68.jpg
# Creating...DepthData 3/VideoFrames/frame69.jpg
# Creating...DepthData 3/VideoFrames/frame70.jpg
# Creating...DepthData 3/VideoFrames/frame71.jpg
# Creating...DepthData 3/VideoFrames/frame72.jpg
# Creating...DepthData 3/VideoFrames/frame73.jpg
# Creating...DepthData 3/VideoFrames/frame74.jpg
# Creating...DepthData 3/VideoFrames/frame75.jpg
# Printing depth metadata:
# {'pixelFormatType': 'kCVPixelFormatType_DepthFloat32', 'width': 144, 'height': 256, 'bytesPerRow': 576}
# Creating...DepthData 3/DepthMaps/frame0.npy
# Creating...DepthData 3/DepthMaps/frame1.npy
# Creating...DepthData 3/DepthMaps/frame2.npy
# Creating...DepthData 3/DepthMaps/frame3.npy
# Creating...DepthData 3/DepthMaps/frame4.npy
# Creating...DepthData 3/DepthMaps/frame5.npy
# Creating...DepthData 3/DepthMaps/frame6.npy
# Creating...DepthData 3/DepthMaps/frame7.npy
# Creating...DepthData 3/DepthMaps/frame8.npy
# Creating...DepthData 3/DepthMaps/frame9.npy
# Creating...DepthData 3/DepthMaps/frame10.npy
# Creating...DepthData 3/DepthMaps/frame11.npy
# Creating...DepthData 3/DepthMaps/frame12.npy
# Creating...DepthData 3/DepthMaps/frame13.npy
# Creating...DepthData 3/DepthMaps/frame14.npy
# Creating...DepthData 3/DepthMaps/frame15.npy
# Creating...DepthData 3/DepthMaps/frame16.npy
# Creating...DepthData 3/DepthMaps/frame17.npy
# Creating...DepthData 3/DepthMaps/frame18.npy
# Creating...DepthData 3/DepthMaps/frame19.npy
# Creating...DepthData 3/DepthMaps/frame20.npy
# Creating...DepthData 3/DepthMaps/frame21.npy
# Creating...DepthData 3/DepthMaps/frame22.npy
# Creating...DepthData 3/DepthMaps/frame23.npy
# Creating...DepthData 3/DepthMaps/frame24.npy
# Creating...DepthData 3/DepthMaps/frame25.npy
# Creating...DepthData 3/DepthMaps/frame26.npy
# Creating...DepthData 3/DepthMaps/frame27.npy
# Creating...DepthData 3/DepthMaps/frame28.npy
# Creating...DepthData 3/DepthMaps/frame29.npy
# Creating...DepthData 3/DepthMaps/frame30.npy
# Creating...DepthData 3/DepthMaps/frame31.npy
# Creating...DepthData 3/DepthMaps/frame32.npy
# Creating...DepthData 3/DepthMaps/frame33.npy
# Creating...DepthData 3/DepthMaps/frame34.npy
# Creating...DepthData 3/DepthMaps/frame35.npy
# Creating...DepthData 3/DepthMaps/frame36.npy
# Creating...DepthData 3/DepthMaps/frame37.npy
# Creating...DepthData 3/DepthMaps/frame38.npy
# Creating...DepthData 3/DepthMaps/frame39.npy
# Creating...DepthData 3/DepthMaps/frame40.npy
# Creating...DepthData 3/DepthMaps/frame41.npy
# Creating...DepthData 3/DepthMaps/frame42.npy
# Creating...DepthData 3/DepthMaps/frame43.npy
# Creating...DepthData 3/DepthMaps/frame44.npy
# Creating...DepthData 3/DepthMaps/frame45.npy
# Creating...DepthData 3/DepthMaps/frame46.npy
# Creating...DepthData 3/DepthMaps/frame47.npy
# Creating...DepthData 3/DepthMaps/frame48.npy
# Creating...DepthData 3/DepthMaps/frame49.npy
# Creating...DepthData 3/DepthMaps/frame50.npy
# Creating...DepthData 3/DepthMaps/frame51.npy
# Creating...DepthData 3/DepthMaps/frame52.npy
# Creating...DepthData 3/DepthMaps/frame53.npy
# Creating...DepthData 3/DepthMaps/frame54.npy
# Creating...DepthData 3/DepthMaps/frame55.npy
# Creating...DepthData 3/DepthMaps/frame56.npy
# Creating...DepthData 3/DepthMaps/frame57.npy
# Creating...DepthData 3/DepthMaps/frame58.npy
# Creating...DepthData 3/DepthMaps/frame59.npy
# Creating...DepthData 3/DepthMaps/frame60.npy
# Creating...DepthData 3/DepthMaps/frame61.npy
# Creating...DepthData 3/DepthMaps/frame62.npy
# Creating...DepthData 3/DepthMaps/frame63.npy
# Creating...DepthData 3/DepthMaps/frame64.npy
# Creating...DepthData 3/DepthMaps/frame65.npy
# Creating...DepthData 3/DepthMaps/frame66.npy
# Creating...DepthData 3/DepthMaps/frame67.npy
# Creating...DepthData 3/DepthMaps/frame68.npy
# Creating...DepthData 3/DepthMaps/frame69.npy
# Creating...DepthData 3/DepthMaps/frame70.npy
# Creating...DepthData 3/DepthMaps/frame71.npy
# Creating...DepthData 3/DepthMaps/frame72.npy
# Creating...DepthData 3/DepthMaps/frame73.npy
# Creating...DepthData 3/DepthMaps/frame74.npy
# Creating...DepthData 3/DepthMaps/frame75.npy
# Number of video frames:76
# Number of depth maps:76
# /var/folders/fr/89d7f2117vq739rlbm5st42r0000gn/T/ipykernel_69816/2144372381.py:117: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
# Creating...DepthData 4/VideoFrames/frame0.jpg
# Creating...DepthData 4/VideoFrames/frame1.jpg
# Creating...DepthData 4/VideoFrames/frame2.jpg
# Creating...DepthData 4/VideoFrames/frame3.jpg
# Creating...DepthData 4/VideoFrames/frame4.jpg
# Creating...DepthData 4/VideoFrames/frame5.jpg
# Creating...DepthData 4/VideoFrames/frame6.jpg
# Creating...DepthData 4/VideoFrames/frame7.jpg
# Creating...DepthData 4/VideoFrames/frame8.jpg
# Creating...DepthData 4/VideoFrames/frame9.jpg
# Creating...DepthData 4/VideoFrames/frame10.jpg
# Creating...DepthData 4/VideoFrames/frame11.jpg
# Creating...DepthData 4/VideoFrames/frame12.jpg
# Creating...DepthData 4/VideoFrames/frame13.jpg
# Creating...DepthData 4/VideoFrames/frame14.jpg
# Creating...DepthData 4/VideoFrames/frame15.jpg
# Creating...DepthData 4/VideoFrames/frame16.jpg
# Creating...DepthData 4/VideoFrames/frame17.jpg
# Creating...DepthData 4/VideoFrames/frame18.jpg
# Creating...DepthData 4/VideoFrames/frame19.jpg
# Creating...DepthData 4/VideoFrames/frame20.jpg
# Creating...DepthData 4/VideoFrames/frame21.jpg
# Creating...DepthData 4/VideoFrames/frame22.jpg
# Creating...DepthData 4/VideoFrames/frame23.jpg
# Creating...DepthData 4/VideoFrames/frame24.jpg
# Creating...DepthData 4/VideoFrames/frame25.jpg
# Creating...DepthData 4/VideoFrames/frame26.jpg
# Creating...DepthData 4/VideoFrames/frame27.jpg
# Creating...DepthData 4/VideoFrames/frame28.jpg
# Creating...DepthData 4/VideoFrames/frame29.jpg
# Creating...DepthData 4/VideoFrames/frame30.jpg
# Creating...DepthData 4/VideoFrames/frame31.jpg
# Creating...DepthData 4/VideoFrames/frame32.jpg
# Creating...DepthData 4/VideoFrames/frame33.jpg
# Creating...DepthData 4/VideoFrames/frame34.jpg
# Creating...DepthData 4/VideoFrames/frame35.jpg
# Creating...DepthData 4/VideoFrames/frame36.jpg
# Creating...DepthData 4/VideoFrames/frame37.jpg
# Creating...DepthData 4/VideoFrames/frame38.jpg
# Creating...DepthData 4/VideoFrames/frame39.jpg
# Creating...DepthData 4/VideoFrames/frame40.jpg
# Creating...DepthData 4/VideoFrames/frame41.jpg
# Creating...DepthData 4/VideoFrames/frame42.jpg
# Creating...DepthData 4/VideoFrames/frame43.jpg
# Creating...DepthData 4/VideoFrames/frame44.jpg
# Creating...DepthData 4/VideoFrames/frame45.jpg
# Creating...DepthData 4/VideoFrames/frame46.jpg
# Creating...DepthData 4/VideoFrames/frame47.jpg
# Creating...DepthData 4/VideoFrames/frame48.jpg
# Creating...DepthData 4/VideoFrames/frame49.jpg
# Creating...DepthData 4/VideoFrames/frame50.jpg
# Creating...DepthData 4/VideoFrames/frame51.jpg
# Creating...DepthData 4/VideoFrames/frame52.jpg
# Creating...DepthData 4/VideoFrames/frame53.jpg
# Creating...DepthData 4/VideoFrames/frame54.jpg
# Creating...DepthData 4/VideoFrames/frame55.jpg
# Creating...DepthData 4/VideoFrames/frame56.jpg
# Creating...DepthData 4/VideoFrames/frame57.jpg
# Creating...DepthData 4/VideoFrames/frame58.jpg
# Creating...DepthData 4/VideoFrames/frame59.jpg
# Creating...DepthData 4/VideoFrames/frame60.jpg
# Creating...DepthData 4/VideoFrames/frame61.jpg
# Creating...DepthData 4/VideoFrames/frame62.jpg
# Creating...DepthData 4/VideoFrames/frame63.jpg
# Creating...DepthData 4/VideoFrames/frame64.jpg
# Creating...DepthData 4/VideoFrames/frame65.jpg
# Creating...DepthData 4/VideoFrames/frame66.jpg
# Creating...DepthData 4/VideoFrames/frame67.jpg
# Creating...DepthData 4/VideoFrames/frame68.jpg
# Creating...DepthData 4/VideoFrames/frame69.jpg
# Creating...DepthData 4/VideoFrames/frame70.jpg
# Creating...DepthData 4/VideoFrames/frame71.jpg
# Creating...DepthData 4/VideoFrames/frame72.jpg
# Creating...DepthData 4/VideoFrames/frame73.jpg
# Creating...DepthData 4/VideoFrames/frame74.jpg
# Creating...DepthData 4/VideoFrames/frame75.jpg
# Creating...DepthData 4/VideoFrames/frame76.jpg
# Creating...DepthData 4/VideoFrames/frame77.jpg
# Creating...DepthData 4/VideoFrames/frame78.jpg
# Creating...DepthData 4/VideoFrames/frame79.jpg
# Creating...DepthData 4/VideoFrames/frame80.jpg
# Creating...DepthData 4/VideoFrames/frame81.jpg
# Creating...DepthData 4/VideoFrames/frame82.jpg
# Creating...DepthData 4/VideoFrames/frame83.jpg
# Creating...DepthData 4/VideoFrames/frame84.jpg
# Creating...DepthData 4/VideoFrames/frame85.jpg
# Creating...DepthData 4/VideoFrames/frame86.jpg
# Creating...DepthData 4/VideoFrames/frame87.jpg
# Creating...DepthData 4/VideoFrames/frame88.jpg
# Creating...DepthData 4/VideoFrames/frame89.jpg
# Creating...DepthData 4/VideoFrames/frame90.jpg
# Creating...DepthData 4/VideoFrames/frame91.jpg
# Creating...DepthData 4/VideoFrames/frame92.jpg
# Creating...DepthData 4/VideoFrames/frame93.jpg
# Creating...DepthData 4/VideoFrames/frame94.jpg
# Creating...DepthData 4/VideoFrames/frame95.jpg
# Creating...DepthData 4/VideoFrames/frame96.jpg
# Creating...DepthData 4/VideoFrames/frame97.jpg
# Creating...DepthData 4/VideoFrames/frame98.jpg
# Printing depth metadata:
# {'pixelFormatType': 'kCVPixelFormatType_DepthFloat32', 'width': 144, 'height': 256, 'bytesPerRow': 576}
# Creating...DepthData 4/DepthMaps/frame0.npy
# Creating...DepthData 4/DepthMaps/frame1.npy
# Creating...DepthData 4/DepthMaps/frame2.npy
# Creating...DepthData 4/DepthMaps/frame3.npy
# Creating...DepthData 4/DepthMaps/frame4.npy
# Creating...DepthData 4/DepthMaps/frame5.npy
# Creating...DepthData 4/DepthMaps/frame6.npy
# Creating...DepthData 4/DepthMaps/frame7.npy
# Creating...DepthData 4/DepthMaps/frame8.npy
# Creating...DepthData 4/DepthMaps/frame9.npy
# Creating...DepthData 4/DepthMaps/frame10.npy
# Creating...DepthData 4/DepthMaps/frame11.npy
# Creating...DepthData 4/DepthMaps/frame12.npy
# Creating...DepthData 4/DepthMaps/frame13.npy
# Creating...DepthData 4/DepthMaps/frame14.npy
# Creating...DepthData 4/DepthMaps/frame15.npy
# Creating...DepthData 4/DepthMaps/frame16.npy
# Creating...DepthData 4/DepthMaps/frame17.npy
# Creating...DepthData 4/DepthMaps/frame18.npy
# Creating...DepthData 4/DepthMaps/frame19.npy
# Creating...DepthData 4/DepthMaps/frame20.npy
# Creating...DepthData 4/DepthMaps/frame21.npy
# Creating...DepthData 4/DepthMaps/frame22.npy
# Creating...DepthData 4/DepthMaps/frame23.npy
# Creating...DepthData 4/DepthMaps/frame24.npy
# Creating...DepthData 4/DepthMaps/frame25.npy
# Creating...DepthData 4/DepthMaps/frame26.npy
# Creating...DepthData 4/DepthMaps/frame27.npy
# Creating...DepthData 4/DepthMaps/frame28.npy
# Creating...DepthData 4/DepthMaps/frame29.npy
# Creating...DepthData 4/DepthMaps/frame30.npy
# Creating...DepthData 4/DepthMaps/frame31.npy
# Creating...DepthData 4/DepthMaps/frame32.npy
# Creating...DepthData 4/DepthMaps/frame33.npy
# Creating...DepthData 4/DepthMaps/frame34.npy
# Creating...DepthData 4/DepthMaps/frame35.npy
# Creating...DepthData 4/DepthMaps/frame36.npy
# Creating...DepthData 4/DepthMaps/frame37.npy
# Creating...DepthData 4/DepthMaps/frame38.npy
# Creating...DepthData 4/DepthMaps/frame39.npy
# Creating...DepthData 4/DepthMaps/frame40.npy
# Creating...DepthData 4/DepthMaps/frame41.npy
# Creating...DepthData 4/DepthMaps/frame42.npy
# Creating...DepthData 4/DepthMaps/frame43.npy
# Creating...DepthData 4/DepthMaps/frame44.npy
# Creating...DepthData 4/DepthMaps/frame45.npy
# Creating...DepthData 4/DepthMaps/frame46.npy
# Creating...DepthData 4/DepthMaps/frame47.npy
# Creating...DepthData 4/DepthMaps/frame48.npy
# Creating...DepthData 4/DepthMaps/frame49.npy
# Creating...DepthData 4/DepthMaps/frame50.npy
# Creating...DepthData 4/DepthMaps/frame51.npy
# Creating...DepthData 4/DepthMaps/frame52.npy
# Creating...DepthData 4/DepthMaps/frame53.npy
# Creating...DepthData 4/DepthMaps/frame54.npy
# Creating...DepthData 4/DepthMaps/frame55.npy
# Creating...DepthData 4/DepthMaps/frame56.npy
# Creating...DepthData 4/DepthMaps/frame57.npy
# Creating...DepthData 4/DepthMaps/frame58.npy
# Creating...DepthData 4/DepthMaps/frame59.npy
# Creating...DepthData 4/DepthMaps/frame60.npy
# Creating...DepthData 4/DepthMaps/frame61.npy
# Creating...DepthData 4/DepthMaps/frame62.npy
# Creating...DepthData 4/DepthMaps/frame63.npy
# Creating...DepthData 4/DepthMaps/frame64.npy
# Creating...DepthData 4/DepthMaps/frame65.npy
# Creating...DepthData 4/DepthMaps/frame66.npy
# Creating...DepthData 4/DepthMaps/frame67.npy
# Creating...DepthData 4/DepthMaps/frame68.npy
# Creating...DepthData 4/DepthMaps/frame69.npy
# Creating...DepthData 4/DepthMaps/frame70.npy
# Creating...DepthData 4/DepthMaps/frame71.npy
# Creating...DepthData 4/DepthMaps/frame72.npy
# Creating...DepthData 4/DepthMaps/frame73.npy
# Creating...DepthData 4/DepthMaps/frame74.npy
# Creating...DepthData 4/DepthMaps/frame75.npy
# Creating...DepthData 4/DepthMaps/frame76.npy
# Creating...DepthData 4/DepthMaps/frame77.npy
# Creating...DepthData 4/DepthMaps/frame78.npy
# Creating...DepthData 4/DepthMaps/frame79.npy
# Creating...DepthData 4/DepthMaps/frame80.npy
# Creating...DepthData 4/DepthMaps/frame81.npy
# Creating...DepthData 4/DepthMaps/frame82.npy
# Creating...DepthData 4/DepthMaps/frame83.npy
# Creating...DepthData 4/DepthMaps/frame84.npy
# Creating...DepthData 4/DepthMaps/frame85.npy
# Creating...DepthData 4/DepthMaps/frame86.npy
# Creating...DepthData 4/DepthMaps/frame87.npy
# Creating...DepthData 4/DepthMaps/frame88.npy
# Creating...DepthData 4/DepthMaps/frame89.npy
# Creating...DepthData 4/DepthMaps/frame90.npy
# Creating...DepthData 4/DepthMaps/frame91.npy
# Creating...DepthData 4/DepthMaps/frame92.npy
# Creating...DepthData 4/DepthMaps/frame93.npy
# Creating...DepthData 4/DepthMaps/frame94.npy
# Creating...DepthData 4/DepthMaps/frame95.npy
# Creating...DepthData 4/DepthMaps/frame96.npy
# Creating...DepthData 4/DepthMaps/frame97.npy
# Creating...DepthData 4/DepthMaps/frame98.npy
# Number of video frames:99
# Number of depth maps:99
# Creating...DepthData/VideoFrames/frame0.jpg
# Creating...DepthData/VideoFrames/frame1.jpg
# Creating...DepthData/VideoFrames/frame2.jpg
# Creating...DepthData/VideoFrames/frame3.jpg
# Creating...DepthData/VideoFrames/frame4.jpg
# Creating...DepthData/VideoFrames/frame5.jpg
# Creating...DepthData/VideoFrames/frame6.jpg
# Creating...DepthData/VideoFrames/frame7.jpg
# Creating...DepthData/VideoFrames/frame8.jpg
# Creating...DepthData/VideoFrames/frame9.jpg
# Creating...DepthData/VideoFrames/frame10.jpg
# Creating...DepthData/VideoFrames/frame11.jpg
# Creating...DepthData/VideoFrames/frame12.jpg
# Creating...DepthData/VideoFrames/frame13.jpg
# Creating...DepthData/VideoFrames/frame14.jpg
# Creating...DepthData/VideoFrames/frame15.jpg
# Creating...DepthData/VideoFrames/frame16.jpg
# Creating...DepthData/VideoFrames/frame17.jpg
# Creating...DepthData/VideoFrames/frame18.jpg
# Creating...DepthData/VideoFrames/frame19.jpg
# Creating...DepthData/VideoFrames/frame20.jpg
# Creating...DepthData/VideoFrames/frame21.jpg
# Creating...DepthData/VideoFrames/frame22.jpg
# Creating...DepthData/VideoFrames/frame23.jpg
# Creating...DepthData/VideoFrames/frame24.jpg
# Creating...DepthData/VideoFrames/frame25.jpg
# Creating...DepthData/VideoFrames/frame26.jpg
# Creating...DepthData/VideoFrames/frame27.jpg
# Creating...DepthData/VideoFrames/frame28.jpg
# Creating...DepthData/VideoFrames/frame29.jpg
# Creating...DepthData/VideoFrames/frame30.jpg
# Creating...DepthData/VideoFrames/frame31.jpg
# Creating...DepthData/VideoFrames/frame32.jpg
# Creating...DepthData/VideoFrames/frame33.jpg
# Creating...DepthData/VideoFrames/frame34.jpg
# Creating...DepthData/VideoFrames/frame35.jpg
# Creating...DepthData/VideoFrames/frame36.jpg
# Creating...DepthData/VideoFrames/frame37.jpg
# Creating...DepthData/VideoFrames/frame38.jpg
# Creating...DepthData/VideoFrames/frame39.jpg
# Creating...DepthData/VideoFrames/frame40.jpg
# Creating...DepthData/VideoFrames/frame41.jpg
# Creating...DepthData/VideoFrames/frame42.jpg
# Creating...DepthData/VideoFrames/frame43.jpg
# Creating...DepthData/VideoFrames/frame44.jpg
# Creating...DepthData/VideoFrames/frame45.jpg
# Creating...DepthData/VideoFrames/frame46.jpg
# Creating...DepthData/VideoFrames/frame47.jpg
# Creating...DepthData/VideoFrames/frame48.jpg
# Creating...DepthData/VideoFrames/frame49.jpg
# Creating...DepthData/VideoFrames/frame50.jpg
# Creating...DepthData/VideoFrames/frame51.jpg
# Creating...DepthData/VideoFrames/frame52.jpg
# Creating...DepthData/VideoFrames/frame53.jpg
# Creating...DepthData/VideoFrames/frame54.jpg
# Creating...DepthData/VideoFrames/frame55.jpg
# Creating...DepthData/VideoFrames/frame56.jpg
# Creating...DepthData/VideoFrames/frame57.jpg
# Creating...DepthData/VideoFrames/frame58.jpg
# Creating...DepthData/VideoFrames/frame59.jpg
# Creating...DepthData/VideoFrames/frame60.jpg
# Creating...DepthData/VideoFrames/frame61.jpg
# Creating...DepthData/VideoFrames/frame62.jpg
# Creating...DepthData/VideoFrames/frame63.jpg
# Creating...DepthData/VideoFrames/frame64.jpg
# Creating...DepthData/VideoFrames/frame65.jpg
# Creating...DepthData/VideoFrames/frame66.jpg
# Creating...DepthData/VideoFrames/frame67.jpg
# Creating...DepthData/VideoFrames/frame68.jpg
# Creating...DepthData/VideoFrames/frame69.jpg
# Creating...DepthData/VideoFrames/frame70.jpg
# Creating...DepthData/VideoFrames/frame71.jpg
# Creating...DepthData/VideoFrames/frame72.jpg
# Creating...DepthData/VideoFrames/frame73.jpg
# Creating...DepthData/VideoFrames/frame74.jpg
# Creating...DepthData/VideoFrames/frame75.jpg
# Creating...DepthData/VideoFrames/frame76.jpg
# Creating...DepthData/VideoFrames/frame77.jpg
# Creating...DepthData/VideoFrames/frame78.jpg
# Creating...DepthData/VideoFrames/frame79.jpg
# Creating...DepthData/VideoFrames/frame80.jpg
# Creating...DepthData/VideoFrames/frame81.jpg
# Creating...DepthData/VideoFrames/frame82.jpg
# Creating...DepthData/VideoFrames/frame83.jpg
# Creating...DepthData/VideoFrames/frame84.jpg
# Creating...DepthData/VideoFrames/frame85.jpg
# Creating...DepthData/VideoFrames/frame86.jpg
